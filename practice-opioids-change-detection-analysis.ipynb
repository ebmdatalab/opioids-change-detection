# %%
#import libraries required for analysis
from change_detection import functions as chg
from change_detection import *
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from ebmdatalab import bq
from ebmdatalab import charts
from ebmdatalab import maps

# %%
## opioids = chg.ChangeDetection('practice_data_opioid%',measure=True).run() This is commented so the code isn't rerun and files reproduced -its takes circa 30 min per measure
# Out:
# C:\Users\bmackenna\Anaconda3\lib\site-packages\pandas\io\gbq.py:176: FutureWarning: The default value for dialect is changing to "standard" in a future version. Pass in dialect="legacy" or set pandas_gbq.context.dialect="legacy" to disable this warning.
#   **kwargs

# %%
opioids = chg.ChangeDetection('practice_data_opioid%',measure=True)
opioids = opioids.concatenate_outputs()

# %%
opioids = opioids.reset_index()
opioids.head()
# Out:
#                    measure    name  is.nbreak  is.tfirst  is.tfirst.pknown  \
# 0  practice_data_opioidome  A81001          0        NaN               NaN
# 1  practice_data_opioidome  A81002          0        NaN               NaN
# 2  practice_data_opioidome  A81004          0        NaN               NaN
# 3  practice_data_opioidome  A81005          0        NaN               NaN
# 4  practice_data_opioidome  A81006          1        5.0               5.0
#
#    is.tfirst.pknown.offs  is.tfirst.offs  is.tfirst.big  is.slope.ma  \
# 0                    NaN             NaN            NaN          NaN
# 1                    NaN             NaN            NaN          NaN
# 2                    NaN             NaN            NaN          NaN
# 3                    NaN             NaN            NaN          NaN
# 4                    5.0             5.0            5.0   130.919441
#
#    is.slope.ma.prop  is.slope.ma.prop.lev  is.intlev.initlev  \
# 0               NaN                   NaN                NaN
# 1               NaN                   NaN                NaN
# 2               NaN                   NaN                NaN
# 3               NaN                   NaN                NaN
# 4          0.003036              0.517857       42998.525416
#
#    is.intlev.finallev  is.intlev.levd  is.intlev.levdprop
# 0                 NaN             NaN                 NaN
# 1                 NaN             NaN                 NaN
# 2                 NaN             NaN                 NaN
# 3                 NaN             NaN                 NaN
# 4        50330.014139    -7331.488723           -0.170506

# %%
practice_data_opioidome = opioids.loc[(opioids["measure"] == "practice_data_opioidome")]
practice_data_opioidome.head()
# Out:
#                    measure    name  is.nbreak  is.tfirst  is.tfirst.pknown  \
# 0  practice_data_opioidome  A81001          0        NaN               NaN
# 1  practice_data_opioidome  A81002          0        NaN               NaN
# 2  practice_data_opioidome  A81004          0        NaN               NaN
# 3  practice_data_opioidome  A81005          0        NaN               NaN
# 4  practice_data_opioidome  A81006          1        5.0               5.0
#
#    is.tfirst.pknown.offs  is.tfirst.offs  is.tfirst.big  is.slope.ma  \
# 0                    NaN             NaN            NaN          NaN
# 1                    NaN             NaN            NaN          NaN
# 2                    NaN             NaN            NaN          NaN
# 3                    NaN             NaN            NaN          NaN
# 4                    5.0             5.0            5.0   130.919441
#
#    is.slope.ma.prop  is.slope.ma.prop.lev  is.intlev.initlev  \
# 0               NaN                   NaN                NaN
# 1               NaN                   NaN                NaN
# 2               NaN                   NaN                NaN
# 3               NaN                   NaN                NaN
# 4          0.003036              0.517857       42998.525416
#
#    is.intlev.finallev  is.intlev.levd  is.intlev.levdprop
# 0                 NaN             NaN                 NaN
# 1                 NaN             NaN                 NaN
# 2                 NaN             NaN                 NaN
# 3                 NaN             NaN                 NaN
# 4        50330.014139    -7331.488723           -0.170506

# %%
practice_data_opioidspercent = opioids.loc[(opioids["measure"] == "practice_data_opioidspercent")]
practice_data_opioidspercent.head()
# Out:
#                             measure    name  is.nbreak  is.tfirst  \
# 14799  practice_data_opioidspercent  A81001          2       47.0
# 14800  practice_data_opioidspercent  A81002          0        NaN
# 14801  practice_data_opioidspercent  A81004          1       20.0
# 14802  practice_data_opioidspercent  A81005          2       21.0
# 14803  practice_data_opioidspercent  A81006          2       19.0
#
#        is.tfirst.pknown  is.tfirst.pknown.offs  is.tfirst.offs  is.tfirst.big  \
# 14799              47.0                   49.0            49.0           49.0
# 14800               NaN                    NaN             NaN            NaN
# 14801              20.0                   20.0            20.0           20.0
# 14802              21.0                   22.0            22.0           22.0
# 14803              19.0                   37.0            37.0           19.0
#
#        is.slope.ma  is.slope.ma.prop  is.slope.ma.prop.lev  is.intlev.initlev  \
# 14799    -0.014454         -0.045485              0.566586           0.262095
# 14800          NaN               NaN                   NaN                NaN
# 14801    -0.001851         -0.005808              0.523810           0.320562
# 14802    -0.006190         -0.020519              0.592839           0.106276
# 14803     0.003499          0.024312              0.619252           0.140401
#
#        is.intlev.finallev  is.intlev.levd  is.intlev.levdprop
# 14799            0.185561        0.076534            0.292010
# 14800                 NaN             NaN                 NaN
# 14801            0.242812        0.077750            0.242544
# 14802            0.054070        0.052206            0.491231
# 14803            0.146050       -0.005650           -0.040239

# %%
practice_data_opioidper1000 = opioids.loc[(opioids["measure"] == "practice_data_opioidper1000")]
practice_data_opioidper1000.head()
# Out:
#                           measure    name  is.nbreak  is.tfirst  \
# 7434  practice_data_opioidper1000  A81001          0        NaN
# 7435  practice_data_opioidper1000  A81002          0        NaN
# 7436  practice_data_opioidper1000  A81004          0        NaN
# 7437  practice_data_opioidper1000  A81005          3       20.0
# 7438  practice_data_opioidper1000  A81006          2       17.0
#
#       is.tfirst.pknown  is.tfirst.pknown.offs  is.tfirst.offs  is.tfirst.big  \
# 7434               NaN                    NaN             NaN            NaN
# 7435               NaN                    NaN             NaN            NaN
# 7436               NaN                    NaN             NaN            NaN
# 7437              20.0                   20.0            20.0           22.0
# 7438              17.0                   17.0            17.0           17.0
#
#       is.slope.ma  is.slope.ma.prop  is.slope.ma.prop.lev  is.intlev.initlev  \
# 7434          NaN               NaN                   NaN                NaN
# 7435          NaN               NaN                   NaN                NaN
# 7436          NaN               NaN                   NaN                NaN
# 7437    -4.469191         -0.980027              6.611756           1.147182
# 7438     0.060606          0.034765              0.516088           1.682711
#
#       is.intlev.finallev  is.intlev.levd  is.intlev.levdprop
# 7434                 NaN             NaN                 NaN
# 7435                 NaN             NaN                 NaN
# 7436                 NaN             NaN                 NaN
# 7437            0.471236        0.675946            0.589223
# 7438            2.152445       -0.469734           -0.279153
