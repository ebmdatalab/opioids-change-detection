# %%
#import libraries required for analysis
from change_detection import functions as chg
from change_detection import *
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from ebmdatalab import bq
from ebmdatalab import charts
from ebmdatalab import maps

# %%
opioids = chg.ChangeDetection('ccg_data_opioid%',measure=True) ## `.run` - this needs to be in first time
opioids = opioids.concatenate_outputs()

# %%
opioids = opioids.reset_index()
opioids.head()
# Out:
#               measure name  is.nbreak  is.tfirst  is.tfirst.pknown  \
# 0  ccg_data_opioidome  00C          0        NaN               NaN
# 1  ccg_data_opioidome  00D          0        NaN               NaN
# 2  ccg_data_opioidome  00J          0        NaN               NaN
# 3  ccg_data_opioidome  00K          0        NaN               NaN
# 4  ccg_data_opioidome  00L          0        NaN               NaN
#
#    is.tfirst.pknown.offs  is.tfirst.offs  is.tfirst.big  is.slope.ma  \
# 0                    NaN             NaN            NaN          NaN
# 1                    NaN             NaN            NaN          NaN
# 2                    NaN             NaN            NaN          NaN
# 3                    NaN             NaN            NaN          NaN
# 4                    NaN             NaN            NaN          NaN
#
#    is.slope.ma.prop  is.slope.ma.prop.lev  is.intlev.initlev  \
# 0               NaN                   NaN                NaN
# 1               NaN                   NaN                NaN
# 2               NaN                   NaN                NaN
# 3               NaN                   NaN                NaN
# 4               NaN                   NaN                NaN
#
#    is.intlev.finallev  is.intlev.levd  is.intlev.levdprop
# 0                 NaN             NaN                 NaN
# 1                 NaN             NaN                 NaN
# 2                 NaN             NaN                 NaN
# 3                 NaN             NaN                 NaN
# 4                 NaN             NaN                 NaN

# %%
ccg_data_opioidome = opioids.loc[(opioids["measure"] == "ccg_data_opioidome")]
ccg_data_opioidome.head()
# Out:
#               measure name  is.nbreak  is.tfirst  is.tfirst.pknown  \
# 0  ccg_data_opioidome  00C          0        NaN               NaN
# 1  ccg_data_opioidome  00D          0        NaN               NaN
# 2  ccg_data_opioidome  00J          0        NaN               NaN
# 3  ccg_data_opioidome  00K          0        NaN               NaN
# 4  ccg_data_opioidome  00L          0        NaN               NaN
#
#    is.tfirst.pknown.offs  is.tfirst.offs  is.tfirst.big  is.slope.ma  \
# 0                    NaN             NaN            NaN          NaN
# 1                    NaN             NaN            NaN          NaN
# 2                    NaN             NaN            NaN          NaN
# 3                    NaN             NaN            NaN          NaN
# 4                    NaN             NaN            NaN          NaN
#
#    is.slope.ma.prop  is.slope.ma.prop.lev  is.intlev.initlev  \
# 0               NaN                   NaN                NaN
# 1               NaN                   NaN                NaN
# 2               NaN                   NaN                NaN
# 3               NaN                   NaN                NaN
# 4               NaN                   NaN                NaN
#
#    is.intlev.finallev  is.intlev.levd  is.intlev.levdprop
# 0                 NaN             NaN                 NaN
# 1                 NaN             NaN                 NaN
# 2                 NaN             NaN                 NaN
# 3                 NaN             NaN                 NaN
# 4                 NaN             NaN                 NaN

# %%
ccg_data_opioidspercent = opioids.loc[(opioids["measure"] == "ccg_data_opioidspercent")]
ccg_data_opioidspercent.head()
# Out:
#                      measure name  is.nbreak  is.tfirst  is.tfirst.pknown  \
# 382  ccg_data_opioidspercent  00C          2       22.0              22.0
# 383  ccg_data_opioidspercent  00D          1       39.0              39.0
# 384  ccg_data_opioidspercent  00J          3       10.0              10.0
# 385  ccg_data_opioidspercent  00K          1       15.0              15.0
# 386  ccg_data_opioidspercent  00L          1       38.0              38.0
#
#      is.tfirst.pknown.offs  is.tfirst.offs  is.tfirst.big  is.slope.ma  \
# 382                   22.0            22.0           22.0     0.004094
# 383                   39.0            39.0           39.0    -0.000833
# 384                   10.0            10.0           47.0    -0.002402
# 385                   15.0            15.0           15.0    -0.000552
# 386                    NaN             NaN           38.0    -0.001440
#
#      is.slope.ma.prop  is.slope.ma.prop.lev  is.intlev.initlev  \
# 382          0.022296              0.511345           0.179529
# 383         -0.004373              0.521739           0.191262
# 384         -0.012469              0.518656           0.193772
# 385         -0.002357              0.510638           0.234600
# 386         -0.007366              0.541667           0.196952
#
#      is.intlev.finallev  is.intlev.levd  is.intlev.levdprop
# 382            0.187535       -0.008007           -0.044597
# 383            0.172108        0.019153            0.100143
# 384            0.138203        0.055569            0.286774
# 385            0.208669        0.025930            0.110530
# 386            0.162390        0.034561            0.175481

# %%
ccg_data_opioidper1000 = opioids.loc[(opioids["measure"] == "ccg_data_opioidper1000")]
ccg_data_opioidper1000.head()
# Out:
#                     measure name  is.nbreak  is.tfirst  is.tfirst.pknown  \
# 191  ccg_data_opioidper1000  00C          2       20.0              20.0
# 192  ccg_data_opioidper1000  00D          2       17.0              17.0
# 193  ccg_data_opioidper1000  00J          1       49.0              49.0
# 194  ccg_data_opioidper1000  00K          0        NaN               NaN
# 195  ccg_data_opioidper1000  00L          2       17.0              17.0
#
#      is.tfirst.pknown.offs  is.tfirst.offs  is.tfirst.big  is.slope.ma  \
# 191                   35.0            35.0           20.0     0.065739
# 192                   31.0            31.0           17.0     0.033582
# 193                   49.0            49.0           49.0    -0.035633
# 194                    NaN             NaN            NaN          NaN
# 195                   35.0            35.0           35.0    -0.027819
#
#      is.slope.ma.prop  is.slope.ma.prop.lev  is.intlev.initlev  \
# 191          0.022205              0.514286           2.894864
# 192          0.009687              0.553786           3.433336
# 193         -0.014250              0.583333           2.536202
# 194               NaN                   NaN                NaN
# 195         -0.009997              0.885687           2.746126
#
#      is.intlev.finallev  is.intlev.levd  is.intlev.levdprop
# 191            3.022690       -0.127827           -0.044156
# 192            3.493978       -0.060641           -0.017663
# 193            2.108601        0.427602            0.168599
# 194                 NaN             NaN                 NaN
# 195            2.683307        0.062819            0.022876
